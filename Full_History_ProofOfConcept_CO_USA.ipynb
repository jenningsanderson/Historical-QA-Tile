# %% [markdown]
# # Building OSM Full History objects from History Files
#
# > Test case: Colorado, USA

# %%
import osmium as o
import numpy as np
import sys, os, json, pprint, copy
from collections import Counter

# %% [markdown]
# main runtime, unfortuantely it's single threaded.

# %%
class FileHandler(o.SimpleHandler):                                                                                           
    def __init__(self):
        o.SimpleHandler.__init__(self)                                                                                              
        self.w_cnt = 0
        self.n_cnt = 0

    def node(self, n):
        '''
            Only save nodes which have extra attributes...
            TODO: If the first version of a node has 0 tags, but version 2 has tags, then version 1 may not show up in the history... maybe?
        '''
        self.n_cnt +=1
        if n.id in nodes:
            nodes[n.id].add(n)
        elif len(n.tags)>0:
            nodes[n.id] = Node(n)
            
        #Cache these locations:
        if n.id not in node_locations:
            node_locations[n.id] = []

        node_locations[n.id].append({
                'v':n.version,
                'c':n.changeset,
                'g':[n.location.lon, n.location.lat]
            })
        
        if self.n_cnt%10000==0:
            sys.stderr.write("\r{0} nodes processed".format(self.n_cnt))

    def way(self, w):
        self.w_cnt += 1
        if w.id in ways: 
            ways[w.id].add(w)
        else:
            ways[w.id] = Way(w)
        if self.w_cnt%1000==0:
            sys.stderr.write("\r{0} ways processed".format(self.w_cnt))

# %%
class OSMObject:
    def __init__(self, w):
        self.id = w.id
        self.history = []
        self.add(w)
        
    def add(self,w):
        self.history.append(
            {
                'version':w.version,
#                 'deleted':w.deleted, # These are not doing their part
#                 'visible':w.visible, #TODO: Why don't these work properly?
                
                'uid' : w.uid,
                'user': w.user,
                'created_at': w.timestamp.isoformat(),
                'timestamp' : w.timestamp,
                
                'tags': dict( (t.k, t.v) for t in list(w.tags) ),
                'geometry': self.get_geometry(w)
            })
        
    def process_history(self):
        if len(self.history[0]['tags']):
            self.history[0]['new_tags'] = self.history[0]['tags']
            
        if len(self.history)>1:

            #Ensure it's in order
            self.history.sort(key=lambda x: x['version'])
            
            for prev_idx, w in enumerate(self.history[1:]):

                prev_keys  = set(self.history[prev_idx]['tags'])
                these_keys = set(w['tags'])

                new_keys = these_keys - prev_keys
                if len(new_keys) > 0:
                    w['new_tags'] = dict( (k, w['tags'][k]) for k in new_keys)

                del_keys = prev_keys - new_keys - these_keys
                if len(del_keys) > 0:
                    w['deleted_tags'] = dict( (k, self.history[prev_idx]['tags'][k]) for k in del_keys)
                
                changed_tags = {}
                for k in these_keys:
                    if k in prev_keys:
                        if w['tags'][k] != self.history[prev_idx]['tags'][k]:
                            changed_tags[k] = (self.history[prev_idx]['tags'][k], w['tags'][k])
                if len(changed_tags):
                    w['changed_tags'] = changed_tags
                    
                w['seconds_since_last_edit'] = int((w['timestamp'] - self.history[prev_idx]['timestamp']).total_seconds())
                    
    def as_geojson(self, geometries=True):
        geojson = {'type':'Feature'}
        geojson['properties']  = copy.deepcopy(self.history[-1]['tags'])
        geojson['properties']['@id']          = self.id
        geojson['properties']['@created_at']  = self.history[-1]['created_at']
        geojson['properties']['@uid']         = self.history[-1]['uid']
        geojson['properties']['@user']        = self.history[-1]['user']
        geojson['properties']['@version']     = self.history[-1]['version']
        
        geojson['geometry'] = copy.deepcopy(self.history[-1]['geometry'])
        
        if len(self.history)>1:
            geojson['properties']['@object_history'] = copy.deepcopy(self.history)
            
            for idx, hist_obj in enumerate(geojson['properties']['@object_history']):
                if 'timestamp' in hist_obj:
                    del hist_obj['timestamp']
                    
                if 'tags' in hist_obj:
                    del hist_obj['tags']
                
                if idx>0:
                    if hist_obj['geometry']['coordinates'] != geojson['properties']['@object_history'][idx-1]['geometry']['coordinates']:
                        if geometries:
                            hist_obj['geometry_change'] = {
                                'old': geojson['properties']['@object_history'][idx-1]['geometry']['coordinates'],
                                'new': hist_obj['geometry']
                            }
                        else:
                            hist_obj['geometry_change'] = {
                                'old':{'nodes': len(geojson['properties']['@object_history'][idx-1]['geometry']['coordinates'])},
                                'new':{'nodes': len(hist_obj['geometry']['coordinates'])}
                            }
            
            for hist_obj in geojson['properties']['@object_history']:
                del hist_obj['geometry']

#         else:
#             if geometries: 
#                 #There is only 1 entry, so delete the geometry from history
#                 del geojson['properties']['@object_history'][0]['geometry']
#             else:
#                 geojson['properties']['@object_history'][0]['geometry'] = {'nodes':len(geojson['geometry']['coordinates'])}
            
        return geojson
    
    def __str__(self):
        """
            Override str() function so when calling print(), we get back the full information
        """
        string = "ID: {0}; revisions: {1}".format(self.id, len(self.history)-1)
        if len(self.history)>1:
            string += "\n-------------------------------------------------------------------------------"
            for o in self.history:
                string += "\n({0}) - {1} - {2}, Nodes: {3}".format(o['version'], o['user'], o['created_at'], len(o['geometry']['coordinates']))
                if 'new_tags' in o:
                    string += "\n\tNew Tags: {0}".format(o['new_tags'])
                if 'deleted_tags' in o:
                    string += "\n\tDeleted Tags: {0}".format(o['deleted_tags'])
                if 'changed_tags' in o:
                    string += "\n\tChanged Tags: {0}".format(o['changed_tags'])
            string += "\n==============================================================================="
        return string
            
class Way(OSMObject):
    def __init__(self, w):
        self.errors = 0
        OSMObject.__init__(self, w)
    
    def get_geometry(self,w):
        coords = []
        for n in w.nodes:
            #If there are multiple versions, then we sort and take the latest
            if len(node_locations[n.ref]) > 1:
                #Sort by changeset id
                node_locations[n.ref].sort(key=lambda x: x['c'])
                
                # Due to silly error from JOSM or Potlatch, we have to get hacky with this...
                try:
                    c = [x for x in node_locations[n.ref] if not x['c'] > w.changeset][-1]
                except:
                    #just take the first one
                    c = node_locations[n.ref][0]
                coords.append(c['g'])
            else:
                coords.append(node_locations[n.ref][0]['g'])
            
        return {"type":"LineString", "coordinates": coords}
#         try:
#             geom = o.geom.WKBFactory.create_linestring(w.nodes)
#         except Exception as e:
#             self.errors += 1
#             print(context(e))
#             sys.exit(1)
        
class Node(OSMObject):
    def __init__(self, n):
        self.errors = 0
        OSMObject.__init__(self, n)
    
    def get_geometry(self, n):
        return {"type": "Point", "coordinates":[ n.location.lon, n.location.lat]}

# %% [markdown]
# Run the handler to create the objects

# %% [markdown]
# ## Now process the objects

# %%
node_locations = {}
nodes = dict({})
ways  = dict({})
h = FileHandler()
h.apply_file('/data/osm/colorado.osh.pbf', locations=True)
# Out:
# 2180000 nodes processed

# %% [markdown]
# Inspect five node entries:

# %%
#np.random.choice(list(node_locations.values()),5)

# %%
#Actually process the data:
for idx, (w_id, way) in enumerate(ways.items()):
    way.process_history()
    if idx%1000==0:
        sys.stderr.write("\r{0} ways processed".format(idx))
    
for idx, (n_id, node) in enumerate(nodes.items()):
    node.process_history() 
    if idx%1000==0:
        sys.stderr.write("\r{0} nodes processed".format(idx))
# Out:
# 15000 nodes processed

# %%
# Choose sample of data and print it
sample_ways  = np.random.choice(list(ways.keys()),10)
sample_nodes = np.random.choice(list(nodes.keys()),10)

# %%
# for way in [ways[w_id] for w_id in sample_ways]:
#     print(way)
#     pprint.pprint(way.as_geojson())
    
# for node in [nodes[n_id] for n_id in sample_nodes]:
#     print(node)
#     pprint.pprint(node.as_geojson(geometries=False))
#     pprint.pprint(node.as_geojson())
# Out:
# ID: 176457193; revisions: 1
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T07:19:06+00:00, Nodes: 2
# 	New Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '188216192'}
# (2) - woodpeck_fixbot - 2009-12-17T03:57:19+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '188216192'}
# ===============================================================================
# {'geometry': {'coordinates': [-105.263258, 40.025565], 'type': 'Point'},
#  'properties': {'@created_at': '2009-12-17T03:57:19+00:00',
#                 '@id': 176457193,
#                 '@object_history': [{'created_at': '2007-12-18T07:19:06+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '188216192',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-12-17T03:57:19+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '188216192',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 63059893,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.263258, 40.025565], 'type': 'Point'},
#  'properties': {'@created_at': '2009-12-17T03:57:19+00:00',
#                 '@id': 176457193,
#                 '@object_history': [{'created_at': '2007-12-18T07:19:06+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '188216192',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-12-17T03:57:19+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '188216192',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 63059893,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# ID: 176582383; revisions: 4
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T08:49:38+00:00, Nodes: 2
# 	New Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220760486:220751739'}
# (2) - woodpeck_fixbot - 2009-09-18T01:35:42+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220760486:220751739'}
# (3) - GPS_dr - 2009-09-30T07:20:45+00:00, Nodes: 2
# (4) - DavidJDBA - 2009-10-25T01:21:15+00:00, Nodes: 2
# (5) - mattchn - 2016-02-16T03:33:59+00:00, Nodes: 2
# ===============================================================================
# {'geometry': {'coordinates': [-105.2396784, 40.0461982], 'type': 'Point'},
#  'properties': {'@created_at': '2016-02-16T03:33:59+00:00',
#                 '@id': 176582383,
#                 '@object_history': [{'created_at': '2007-12-18T08:49:38+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220760486:220751739',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-09-18T01:35:42+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220760486:220751739',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 55269964,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2},
#                                     {'created_at': '2009-09-30T07:20:45+00:00',
#                                      'geometry_change': {'new': {'nodes': 2},
#                                                          'old': {'nodes': 2}},
#                                      'seconds_since_last_edit': 1057503,
#                                      'uid': 117055,
#                                      'user': 'GPS_dr',
#                                      'version': 3},
#                                     {'created_at': '2009-10-25T01:21:15+00:00',
#                                      'geometry_change': {'new': {'nodes': 2},
#                                                          'old': {'nodes': 2}},
#                                      'seconds_since_last_edit': 2138430,
#                                      'uid': 139555,
#                                      'user': 'DavidJDBA',
#                                      'version': 4},
#                                     {'created_at': '2016-02-16T03:33:59+00:00',
#                                      'geometry_change': {'new': {'nodes': 2},
#                                                          'old': {'nodes': 2}},
#                                      'seconds_since_last_edit': 199159964,
#                                      'uid': 1778953,
#                                      'user': 'mattchn',
#                                      'version': 5}],
#                 '@uid': 1778953,
#                 '@user': 'mattchn',
#                 '@version': 5},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.2396784, 40.0461982], 'type': 'Point'},
#  'properties': {'@created_at': '2016-02-16T03:33:59+00:00',
#                 '@id': 176582383,
#                 '@object_history': [{'created_at': '2007-12-18T08:49:38+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220760486:220751739',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-09-18T01:35:42+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220760486:220751739',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 55269964,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2},
#                                     {'created_at': '2009-09-30T07:20:45+00:00',
#                                      'geometry_change': {'new': {'coordinates': [-105.2400253,
#                                                                                  40.0459077],
#                                                                  'type': 'Point'},
#                                                          'old': [-105.24026,
#                                                                  40.045734]},
#                                      'seconds_since_last_edit': 1057503,
#                                      'uid': 117055,
#                                      'user': 'GPS_dr',
#                                      'version': 3},
#                                     {'created_at': '2009-10-25T01:21:15+00:00',
#                                      'geometry_change': {'new': {'coordinates': [-105.2396595,
#                                                                                  40.046186],
#                                                                  'type': 'Point'},
#                                                          'old': [-105.2400253,
#                                                                  40.0459077]},
#                                      'seconds_since_last_edit': 2138430,
#                                      'uid': 139555,
#                                      'user': 'DavidJDBA',
#                                      'version': 4},
#                                     {'created_at': '2016-02-16T03:33:59+00:00',
#                                      'geometry_change': {'new': {'coordinates': [-105.2396784,
#                                                                                  40.0461982],
#                                                                  'type': 'Point'},
#                                                          'old': [-105.2396595,
#                                                                  40.046186]},
#                                      'seconds_since_last_edit': 199159964,
#                                      'uid': 1778953,
#                                      'user': 'mattchn',
#                                      'version': 5}],
#                 '@uid': 1778953,
#                 '@user': 'mattchn',
#                 '@version': 5},
#  'type': 'Feature'}
# ID: 2703445617; revisions: 0
# {'geometry': {'coordinates': [-105.2719931, 40.0070815], 'type': 'Point'},
#  'properties': {'@created_at': '2014-03-05T23:48:13+00:00',
#                 '@id': 2703445617,
#                 '@uid': 1952288,
#                 '@user': 'jade7800',
#                 '@version': 1,
#                 'entrance': 'yes'},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.2719931, 40.0070815], 'type': 'Point'},
#  'properties': {'@created_at': '2014-03-05T23:48:13+00:00',
#                 '@id': 2703445617,
#                 '@uid': 1952288,
#                 '@user': 'jade7800',
#                 '@version': 1,
#                 'entrance': 'yes'},
#  'type': 'Feature'}
# ID: 176574096; revisions: 1
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T08:43:58+00:00, Nodes: 2
# 	New Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220751712:220751762:188162984'}
# (2) - woodpeck_fixbot - 2009-11-10T11:28:29+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220751712:220751762:188162984'}
# ===============================================================================
# {'geometry': {'coordinates': [-105.238921, 40.0346], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-10T11:28:29+00:00',
#                 '@id': 176574096,
#                 '@object_history': [{'created_at': '2007-12-18T08:43:58+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220751712:220751762:188162984',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-10T11:28:29+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220751712:220751762:188162984',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 59885071,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.238921, 40.0346], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-10T11:28:29+00:00',
#                 '@id': 176574096,
#                 '@object_history': [{'created_at': '2007-12-18T08:43:58+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220751712:220751762:188162984',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-10T11:28:29+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220751712:220751762:188162984',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 59885071,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# ID: 176429480; revisions: 4
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T06:58:24+00:00, Nodes: 2
# 	New Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220750707'}
# (2) - DavidJDBA - 2009-10-30T02:28:27+00:00, Nodes: 2
# (3) - DavidJDBA - 2009-10-30T02:55:28+00:00, Nodes: 2
# (4) - woodpeck_fixbot - 2009-11-10T10:55:35+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220750707'}
# (5) - mattchn - 2016-02-19T03:17:55+00:00, Nodes: 2
# ===============================================================================
# {'geometry': {'coordinates': [-105.2572271, 40.0290908], 'type': 'Point'},
#  'properties': {'@created_at': '2016-02-19T03:17:55+00:00',
#                 '@id': 176429480,
#                 '@object_history': [{'created_at': '2007-12-18T06:58:24+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220750707',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-10-30T02:28:27+00:00',
#                                      'geometry_change': {'new': {'nodes': 2},
#                                                          'old': {'nodes': 2}},
#                                      'seconds_since_last_edit': 58908603,
#                                      'uid': 139555,
#                                      'user': 'DavidJDBA',
#                                      'version': 2},
#                                     {'created_at': '2009-10-30T02:55:28+00:00',
#                                      'geometry_change': {'new': {'nodes': 2},
#                                                          'old': {'nodes': 2}},
#                                      'seconds_since_last_edit': 1621,
#                                      'uid': 139555,
#                                      'user': 'DavidJDBA',
#                                      'version': 3},
#                                     {'created_at': '2009-11-10T10:55:35+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220750707',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 979207,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 4},
#                                     {'created_at': '2016-02-19T03:17:55+00:00',
#                                      'geometry_change': {'new': {'nodes': 2},
#                                                          'old': {'nodes': 2}},
#                                      'seconds_since_last_edit': 198001340,
#                                      'uid': 1778953,
#                                      'user': 'mattchn',
#                                      'version': 5}],
#                 '@uid': 1778953,
#                 '@user': 'mattchn',
#                 '@version': 5},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.2572271, 40.0290908], 'type': 'Point'},
#  'properties': {'@created_at': '2016-02-19T03:17:55+00:00',
#                 '@id': 176429480,
#                 '@object_history': [{'created_at': '2007-12-18T06:58:24+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220750707',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-10-30T02:28:27+00:00',
#                                      'geometry_change': {'new': {'coordinates': [-105.2574882,
#                                                                                  40.0290751],
#                                                                  'type': 'Point'},
#                                                          'old': [-105.257473,
#                                                                  40.029084]},
#                                      'seconds_since_last_edit': 58908603,
#                                      'uid': 139555,
#                                      'user': 'DavidJDBA',
#                                      'version': 2},
#                                     {'created_at': '2009-10-30T02:55:28+00:00',
#                                      'geometry_change': {'new': {'coordinates': [-105.2574403,
#                                                                                  40.0290795],
#                                                                  'type': 'Point'},
#                                                          'old': [-105.2574882,
#                                                                  40.0290751]},
#                                      'seconds_since_last_edit': 1621,
#                                      'uid': 139555,
#                                      'user': 'DavidJDBA',
#                                      'version': 3},
#                                     {'created_at': '2009-11-10T10:55:35+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220750707',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 979207,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 4},
#                                     {'created_at': '2016-02-19T03:17:55+00:00',
#                                      'geometry_change': {'new': {'coordinates': [-105.2572271,
#                                                                                  40.0290908],
#                                                                  'type': 'Point'},
#                                                          'old': [-105.2574403,
#                                                                  40.0290795]},
#                                      'seconds_since_last_edit': 198001340,
#                                      'uid': 1778953,
#                                      'user': 'mattchn',
#                                      'version': 5}],
#                 '@uid': 1778953,
#                 '@user': 'mattchn',
#                 '@version': 5},
#  'type': 'Feature'}
# ID: 176408560; revisions: 1
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T06:43:28+00:00, Nodes: 2
# 	New Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220750532:220751432:220750547'}
# (2) - woodpeck_fixbot - 2009-11-10T10:51:13+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '220750532:220751432:220750547'}
# ===============================================================================
# {'geometry': {'coordinates': [-105.292684, 40.029879], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-10T10:51:13+00:00',
#                 '@id': 176408560,
#                 '@object_history': [{'created_at': '2007-12-18T06:43:28+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220750532:220751432:220750547',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-10T10:51:13+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220750532:220751432:220750547',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 59890065,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.292684, 40.029879], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-10T10:51:13+00:00',
#                 '@id': 176408560,
#                 '@object_history': [{'created_at': '2007-12-18T06:43:28+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '220750532:220751432:220750547',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-10T10:51:13+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '220750532:220751432:220750547',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 59890065,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# ID: 176574839; revisions: 1
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T08:44:26+00:00, Nodes: 2
# 	New Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '188160829:188160830:188184900:220758958'}
# (2) - woodpeck_fixbot - 2009-11-10T11:28:39+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '188160829:188160830:188184900:220758958'}
# ===============================================================================
# {'geometry': {'coordinates': [-105.267501, 40.039954], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-10T11:28:39+00:00',
#                 '@id': 176574839,
#                 '@object_history': [{'created_at': '2007-12-18T08:44:26+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '188160829:188160830:188184900:220758958',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-10T11:28:39+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '188160829:188160830:188184900:220758958',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 59885053,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.267501, 40.039954], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-10T11:28:39+00:00',
#                 '@id': 176574839,
#                 '@object_history': [{'created_at': '2007-12-18T08:44:26+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '188160829:188160830:188184900:220758958',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-10T11:28:39+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '188160829:188160830:188184900:220758958',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 59885053,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# ID: 176528101; revisions: 0
# {'geometry': {'coordinates': [-105.292364, 40.015258], 'type': 'Point'},
#  'properties': {'@created_at': '2007-12-18T08:11:52+00:00',
#                 '@id': 176528101,
#                 '@uid': 7168,
#                 '@user': 'DaveHansenTiger',
#                 '@version': 1,
#                 'source': 'tiger_import_dch_v0.6_20070809',
#                 'tiger:county': 'Boulder, CO',
#                 'tiger:tlid': '220750573:220750575',
#                 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.292364, 40.015258], 'type': 'Point'},
#  'properties': {'@created_at': '2007-12-18T08:11:52+00:00',
#                 '@id': 176528101,
#                 '@uid': 7168,
#                 '@user': 'DaveHansenTiger',
#                 '@version': 1,
#                 'source': 'tiger_import_dch_v0.6_20070809',
#                 'tiger:county': 'Boulder, CO',
#                 'tiger:tlid': '220750573:220750575',
#                 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#  'type': 'Feature'}
# ID: 176426925; revisions: 0
# {'geometry': {'coordinates': [-105.233207, 39.996725], 'type': 'Point'},
#  'properties': {'@created_at': '2007-12-18T06:56:35+00:00',
#                 '@id': 176426925,
#                 '@uid': 7168,
#                 '@user': 'DaveHansenTiger',
#                 '@version': 1,
#                 'source': 'tiger_import_dch_v0.6_20070809',
#                 'tiger:county': 'Boulder, CO',
#                 'tiger:tlid': '188231741:188231742:188213351:188213352',
#                 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.233207, 39.996725], 'type': 'Point'},
#  'properties': {'@created_at': '2007-12-18T06:56:35+00:00',
#                 '@id': 176426925,
#                 '@uid': 7168,
#                 '@user': 'DaveHansenTiger',
#                 '@version': 1,
#                 'source': 'tiger_import_dch_v0.6_20070809',
#                 'tiger:county': 'Boulder, CO',
#                 'tiger:tlid': '188231741:188231742:188213351:188213352',
#                 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#  'type': 'Feature'}
# ID: 176460376; revisions: 1
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T07:21:20+00:00, Nodes: 2
# 	New Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '188210433:220748241'}
# (2) - woodpeck_fixbot - 2009-12-17T03:57:58+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:county': 'Boulder, CO', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f', 'tiger:tlid': '188210433:220748241'}
# ===============================================================================
# {'geometry': {'coordinates': [-105.199408, 39.971021], 'type': 'Point'},
#  'properties': {'@created_at': '2009-12-17T03:57:58+00:00',
#                 '@id': 176460376,
#                 '@object_history': [{'created_at': '2007-12-18T07:21:20+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '188210433:220748241',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-12-17T03:57:58+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '188210433:220748241',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 63059798,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.199408, 39.971021], 'type': 'Point'},
#  'properties': {'@created_at': '2009-12-17T03:57:58+00:00',
#                 '@id': 176460376,
#                 '@object_history': [{'created_at': '2007-12-18T07:21:20+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Boulder, '
#                                                                   'CO',
#                                                   'tiger:tlid': '188210433:220748241',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-12-17T03:57:58+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Boulder, '
#                                                                       'CO',
#                                                       'tiger:tlid': '188210433:220748241',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-1b7afdac-0ecb-47b2-8901-e595d422ff1f'},
#                                      'seconds_since_last_edit': 63059798,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}

# %%
# Write out the geojsonl file
with open('colorado_history_no_geometry.geojsonl','w') as outFile:
    for w_id, way in ways.items():
        outFile.write(json.dumps(way.as_geojson(geometries=False))+"\n")
    
    for n_id, node in nodes.items():
        outFile.write(json.dumps(node.as_geojson(geometries=False))+"\n")

# %% [markdown]
# Tippecanoe Instructions
#
#     $ tippecanoe -o colorado_history_no_geometry.mbtiles -Pf -ps -pt -pf -pk -Z12 -z12 -d14 -l osm -n osm boulder_history.geojsonl
#
# The geometries are stil _not quite right_... but they're close?

# %%
with open('colorado_history_geometry_diffs.geojsonl','w') as outFile:
    for w_id, way in ways.items():
        outFile.write(json.dumps(way.as_geojson())+"\n")
    
    for n_id, node in nodes.items():
        outFile.write(json.dumps(node.as_geojson())+"\n")
