# %% [markdown]
# # Building OSM Full History objects from History Files
#
# > Test case: Colorado, USA

# %%
import osmium as o
import numpy as np
import sys, os, json, pprint, copy
from collections import Counter

# %% [markdown]
# main runtime, unfortuantely it's single threaded (Can osmium run in parallel in native C?)

# %%
class FileHandler(o.SimpleHandler):                                                                                           
    def __init__(self):
        o.SimpleHandler.__init__(self)                                                                                              
        self.w_cnt = 0
        self.n_cnt = 0

    def node(self, n):
        '''
            Only save nodes which have extra attributes...
            TODO: If the first version of a node has 0 tags, but version 2 has tags, then version 1 may not show up in the history... maybe?
        '''
        self.n_cnt +=1
        if n.id in nodes:
            nodes[n.id].add(n)
        elif len(n.tags)>0:
            nodes[n.id] = Node(n)
            
        #Cache these locations:
        if n.id not in node_locations:
            node_locations[n.id] = []

        node_locations[n.id].append({
                'v':n.version,
                'c':n.changeset,
                'g':[n.location.lon, n.location.lat]
            })
        
        if self.n_cnt%10000==0:
            sys.stderr.write("\r{0} nodes processed".format(self.n_cnt))

    def way(self, w):
        self.w_cnt += 1
        if w.id in ways: 
            ways[w.id].add(w)
        else:
            ways[w.id] = Way(w)
        if self.w_cnt%1000==0:
            sys.stderr.write("\r{0} ways processed".format(self.w_cnt))

# %%
class OSMObject:
    def __init__(self, w):
        self.id = w.id
        self.history = []
        self.add(w)
        
    def add(self,w):
        self.history.append(
            {
                'version':w.version,
#                 'deleted':w.deleted, # These are not doing their part
#                 'visible':w.visible, #TODO: Why don't these work properly?
                
                'uid' : w.uid,
                'user': w.user,
                'created_at': w.timestamp.isoformat(),
                'timestamp' : w.timestamp,
                
                'tags': dict( (t.k, t.v) for t in list(w.tags) ),
                'geometry': self.get_geometry(w)
            })
        
    def process_history(self):
        if len(self.history[0]['tags']):
            self.history[0]['new_tags'] = self.history[0]['tags']
            
        if len(self.history)>1:

            #Ensure it's in order
            self.history.sort(key=lambda x: x['version'])
            
            for prev_idx, w in enumerate(self.history[1:]):

                prev_keys  = set(self.history[prev_idx]['tags'])
                these_keys = set(w['tags'])

                new_keys = these_keys - prev_keys
                if len(new_keys) > 0:
                    w['new_tags'] = dict( (k, w['tags'][k]) for k in new_keys)

                del_keys = prev_keys - new_keys - these_keys
                if len(del_keys) > 0:
                    w['deleted_tags'] = dict( (k, self.history[prev_idx]['tags'][k]) for k in del_keys)
                
                changed_tags = {}
                for k in these_keys:
                    if k in prev_keys:
                        if w['tags'][k] != self.history[prev_idx]['tags'][k]:
                            changed_tags[k] = (self.history[prev_idx]['tags'][k], w['tags'][k])
                if len(changed_tags):
                    w['changed_tags'] = changed_tags
                    
                w['seconds_since_last_edit'] = int((w['timestamp'] - self.history[prev_idx]['timestamp']).total_seconds())
                    
    def as_geojson(self, geometries=True):
        geojson = {'type':'Feature'}
        geojson['properties']  = copy.deepcopy(self.history[-1]['tags'])
        geojson['properties']['@id']          = self.id
        geojson['properties']['@created_at']  = self.history[-1]['created_at']
        geojson['properties']['@uid']         = self.history[-1]['uid']
        geojson['properties']['@user']        = self.history[-1]['user']
        geojson['properties']['@version']     = self.history[-1]['version']
        
        geojson['geometry'] = copy.deepcopy(self.history[-1]['geometry'])
        
        if len(self.history)>1:
            geojson['properties']['@object_history'] = copy.deepcopy(self.history)
            
            for idx, hist_obj in enumerate(geojson['properties']['@object_history']):
                if 'timestamp' in hist_obj:
                    del hist_obj['timestamp']
                    
                if 'tags' in hist_obj:
                    del hist_obj['tags']
                
                if idx>0:
                    if hist_obj['geometry']['coordinates'] != geojson['properties']['@object_history'][idx-1]['geometry']['coordinates']:
                        if geometries:
                            hist_obj['geometry_change'] = {
                                'old': geojson['properties']['@object_history'][idx-1]['geometry']['coordinates'],
                                'new': hist_obj['geometry']['coordinates']
                            }
                        else:
                            hist_obj['geometry_change'] = {
                                'old':{'nodes': len(geojson['properties']['@object_history'][idx-1]['geometry']['coordinates'])},
                                'new':{'nodes': len(hist_obj['geometry']['coordinates'])}
                            }
            
            for hist_obj in geojson['properties']['@object_history']:
                del hist_obj['geometry']

#         else:
#             if geometries: 
#                 #There is only 1 entry, so delete the geometry from history
#                 del geojson['properties']['@object_history'][0]['geometry']
#             else:
#                 geojson['properties']['@object_history'][0]['geometry'] = {'nodes':len(geojson['geometry']['coordinates'])}
            
        return geojson
    
    def __str__(self):
        """
            Override str() function so when calling print(), we get back the full information
        """
        string = "ID: {0}; revisions: {1}".format(self.id, len(self.history)-1)
        if len(self.history)>1:
            string += "\n-------------------------------------------------------------------------------"
            for o in self.history:
                string += "\n({0}) - {1} - {2}, Nodes: {3}".format(o['version'], o['user'], o['created_at'], len(o['geometry']['coordinates']))
                if 'new_tags' in o:
                    string += "\n\tNew Tags: {0}".format(o['new_tags'])
                if 'deleted_tags' in o:
                    string += "\n\tDeleted Tags: {0}".format(o['deleted_tags'])
                if 'changed_tags' in o:
                    string += "\n\tChanged Tags: {0}".format(o['changed_tags'])
            string += "\n==============================================================================="
        return string
            
class Way(OSMObject):
    def __init__(self, w):
        self.errors = 0
        OSMObject.__init__(self, w)
    
    def get_geometry(self,w):
        coords = []
        for n in w.nodes:
            #If there are multiple versions, then we sort and take the latest
            if len(node_locations[n.ref]) > 1:
                #Sort by changeset id
                node_locations[n.ref].sort(key=lambda x: x['c'])
                
                # Due to silly error from JOSM or Potlatch, we have to get hacky with this...
                try:
                    c = [x for x in node_locations[n.ref] if not x['c'] > w.changeset][-1]
                except:
                    #just take the first one
                    c = node_locations[n.ref][0]
                coords.append(c['g'])
            else:
                coords.append(node_locations[n.ref][0]['g'])
            
        return {"type":"LineString", "coordinates": coords}
#         try:
#             geom = o.geom.WKBFactory.create_linestring(w.nodes)
#         except Exception as e:
#             self.errors += 1
#             print(context(e))
#             sys.exit(1)
        
class Node(OSMObject):
    def __init__(self, n):
        self.errors = 0
        OSMObject.__init__(self, n)
    
    def get_geometry(self, n):
        return {"type": "Point", "coordinates":[ n.location.lon, n.location.lat]}

# %% [markdown]
# Run the handler to create the objects

# %% [markdown]
# ## Now process the objects

# %%
node_locations = {}
nodes = dict({})
ways  = dict({})
h = FileHandler()
h.apply_file('/data/osm/colorado.osh.pbf', locations=True)
# Out:
# 2764000 ways processed

# %%
#Actually process the data:
for idx, (w_id, way) in enumerate(ways.items()):
    way.process_history()
    if idx%1000==0:
        sys.stderr.write("\r{0} ways processed".format(idx))
# Out:
# 1433000 ways processed

# %%
for idx, (n_id, node) in enumerate(nodes.items()):
    node.process_history() 
    if idx%1000==0:
        sys.stderr.write("\r{0} nodes processed".format(idx))
# Out:
# 3608000 nodes processed

# %%
# Choose sample of data and print it
sample_ways  = np.random.choice(list(ways.keys()),10)
sample_nodes = np.random.choice(list(nodes.keys()),10)

# %%
for way in [ways[w_id] for w_id in sample_ways]:
    print(way)
    pprint.pprint(way.as_geojson())
    
for node in [nodes[n_id] for n_id in sample_nodes]:
    print(node)
    pprint.pprint(node.as_geojson(geometries=False))
    pprint.pprint(node.as_geojson())
# Out:
# ID: 41202559; revisions: 1
# -------------------------------------------------------------------------------
# (1) - SK53_bulk - 2009-09-20T16:35:14+00:00, Nodes: 7
# 	New Tags: {'NHD:FCode': '33600', 'NHD:FType': 'CanalDitch', 'waterway': 'canal', 'NHD:ReachCode': '14010005002698', 'NHD:way_id': '159279264', 'NHD:RESOLUTION': 'High', 'source': 'NHD_import_v0.4_20090914202230', 'NHD:ComID': '159279264', 'SK53_bulk:load': '14010005:FlowLine:59:A', 'name': 'Highline Ditch', 'gnis:feature_id': '00202272', 'attribution': 'NHD'}
# (2) - SK53_bulk - 2009-10-15T21:41:14+00:00, Nodes: 7
# ===============================================================================
# {'geometry': {'coordinates': [[-107.616889, 39.377677],
#                               [-107.616712, 39.378103],
#                               [-107.616061, 39.37846],
#                               [-107.61604, 39.378904],
#                               [-107.615892, 39.379195],
#                               [-107.615843, 39.379212],
#                               [-107.615842, 39.379212]],
#               'type': 'LineString'},
#  'properties': {'@created_at': '2009-10-15T21:41:14+00:00',
#                 '@id': 41202559,
#                 '@object_history': [{'created_at': '2009-09-20T16:35:14+00:00',
#                                      'new_tags': {'NHD:ComID': '159279264',
#                                                   'NHD:FCode': '33600',
#                                                   'NHD:FType': 'CanalDitch',
#                                                   'NHD:RESOLUTION': 'High',
#                                                   'NHD:ReachCode': '14010005002698',
#                                                   'NHD:way_id': '159279264',
#                                                   'SK53_bulk:load': '14010005:FlowLine:59:A',
#                                                   'attribution': 'NHD',
#                                                   'gnis:feature_id': '00202272',
#                                                   'name': 'Highline Ditch',
#                                                   'source': 'NHD_import_v0.4_20090914202230',
#                                                   'waterway': 'canal'},
#                                      'uid': 161206,
#                                      'user': 'SK53_bulk',
#                                      'version': 1},
#                                     {'created_at': '2009-10-15T21:41:14+00:00',
#                                      'seconds_since_last_edit': 2178360,
#                                      'uid': 161206,
#                                      'user': 'SK53_bulk',
#                                      'version': 2}],
#                 '@uid': 161206,
#                 '@user': 'SK53_bulk',
#                 '@version': 2,
#                 'NHD:ComID': '159279264',
#                 'NHD:FCode': '33600',
#                 'NHD:FType': 'CanalDitch',
#                 'NHD:RESOLUTION': 'High',
#                 'NHD:ReachCode': '14010005002698',
#                 'NHD:way_id': '159279264',
#                 'SK53_bulk:load': '14010005:FlowLine:59:A',
#                 'attribution': 'NHD',
#                 'gnis:feature_id': '00202272',
#                 'name': 'Highline Ditch',
#                 'source': 'NHD_import_v0.4_20090914202230',
#                 'waterway': 'canal'},
#  'type': 'Feature'}
# ID: 46461765; revisions: 1
# -------------------------------------------------------------------------------
# (1) - nhd-import - 2009-12-16T18:37:16+00:00, Nodes: 36
# 	New Tags: {'nhd:com_id': '163084383', 'stream': 'ephemeral', 'waterway': 'stream', 'nhd:reach_code': '11020001016859', 'nhd:fcode': '46007', 'nhd:ftype': 'StreamRiver'}
# (2) - DKNOTT - 2013-05-22T21:03:05+00:00, Nodes: 10
# ===============================================================================
# {'geometry': {'coordinates': [[-106.1966382, 39.3510477],
#                               [-106.1967169, 39.3511396],
#                               [-106.1968001, 39.3514066],
#                               [-106.1968847, 39.3514943],
#                               [-106.1970523, 39.3515993],
#                               [-106.1973911, 39.3516765],
#                               [-106.1978937, 39.3518777],
#                               [-106.1981056, 39.3518729],
#                               [-106.1982947, 39.3519475],
#                               [-106.1986405, 39.3519953]],
#               'type': 'LineString'},
#  'properties': {'@created_at': '2013-05-22T21:03:05+00:00',
#                 '@id': 46461765,
#                 '@object_history': [{'created_at': '2009-12-16T18:37:16+00:00',
#                                      'new_tags': {'nhd:com_id': '163084383',
#                                                   'nhd:fcode': '46007',
#                                                   'nhd:ftype': 'StreamRiver',
#                                                   'nhd:reach_code': '11020001016859',
#                                                   'stream': 'ephemeral',
#                                                   'waterway': 'stream'},
#                                      'uid': 206436,
#                                      'user': 'nhd-import',
#                                      'version': 1},
#                                     {'created_at': '2013-05-22T21:03:05+00:00',
#                                      'geometry_change': {'new': [[-106.1966382,
#                                                                   39.3510477],
#                                                                  [-106.1967169,
#                                                                   39.3511396],
#                                                                  [-106.1968001,
#                                                                   39.3514066],
#                                                                  [-106.1968847,
#                                                                   39.3514943],
#                                                                  [-106.1970523,
#                                                                   39.3515993],
#                                                                  [-106.1973911,
#                                                                   39.3516765],
#                                                                  [-106.1978937,
#                                                                   39.3518777],
#                                                                  [-106.1981056,
#                                                                   39.3518729],
#                                                                  [-106.1982947,
#                                                                   39.3519475],
#                                                                  [-106.1986405,
#                                                                   39.3519953]],
#                                                          'old': [[-106.1966382,
#                                                                   39.3510477],
#                                                                  [-106.1966812,
#                                                                   39.3510927],
#                                                                  [-106.1967169,
#                                                                   39.3511396],
#                                                                  [-106.1967355,
#                                                                   39.3511926],
#                                                                  [-106.1967473,
#                                                                   39.3512482],
#                                                                  [-106.196758,
#                                                                   39.3513041],
#                                                                  [-106.1967737,
#                                                                   39.3513577],
#                                                                  [-106.1968001,
#                                                                   39.3514066],
#                                                                  [-106.1968385,
#                                                                   39.3514516],
#                                                                  [-106.1968847,
#                                                                   39.3514943],
#                                                                  [-106.1969371,
#                                                                   39.3515338],
#                                                                  [-106.1969936,
#                                                                   39.3515691],
#                                                                  [-106.1970523,
#                                                                   39.3515993],
#                                                                  [-106.1971147,
#                                                                   39.3516217],
#                                                                  [-106.1971827,
#                                                                   39.3516361],
#                                                                  [-106.1972533,
#                                                                   39.3516472],
#                                                                  [-106.1973238,
#                                                                   39.3516592],
#                                                                  [-106.1973911,
#                                                                   39.3516765],
#                                                                  [-106.1974551,
#                                                                   39.3516995],
#                                                                  [-106.1975181,
#                                                                   39.3517252],
#                                                                  [-106.1975803,
#                                                                   39.3517526],
#                                                                  [-106.1976422,
#                                                                   39.3517805],
#                                                                  [-106.1977041,
#                                                                   39.3518081],
#                                                                  [-106.1977664,
#                                                                   39.3518341],
#                                                                  [-106.1978295,
#                                                                   39.3518577],
#                                                                  [-106.1978937,
#                                                                   39.3518777],
#                                                                  [-106.1979627,
#                                                                   39.3518817],
#                                                                  [-106.1980354,
#                                                                   39.3518729],
#                                                                  [-106.1981056,
#                                                                   39.3518729],
#                                                                  [-106.1981694,
#                                                                   39.3518941],
#                                                                  [-106.1982307,
#                                                                   39.351924],
#                                                                  [-106.1982947,
#                                                                   39.3519475],
#                                                                  [-106.1983627,
#                                                                   39.3519605],
#                                                                  [-106.1984322,
#                                                                   39.3519703],
#                                                                  [-106.1985024,
#                                                                   39.3519781],
#                                                                  [-106.1986405,
#                                                                   39.3519953]]},
#                                      'seconds_since_last_edit': 108267949,
#                                      'uid': 1149057,
#                                      'user': 'DKNOTT',
#                                      'version': 2}],
#                 '@uid': 1149057,
#                 '@user': 'DKNOTT',
#                 '@version': 2,
#                 'nhd:com_id': '163084383',
#                 'nhd:fcode': '46007',
#                 'nhd:ftype': 'StreamRiver',
#                 'nhd:reach_code': '11020001016859',
#                 'stream': 'ephemeral',
#                 'waterway': 'stream'},
#  'type': 'Feature'}
# ID: 41062148; revisions: 1
# -------------------------------------------------------------------------------
# (1) - SK53_bulk - 2009-09-18T16:42:36+00:00, Nodes: 11
# 	New Tags: {'NHD:FCode': '46006', 'NHD:FType': 'StreamRiver', 'waterway': 'stream', 'NHD:ReachCode': '14010005000465', 'NHD:way_id': '159287224', 'NHD:RESOLUTION': 'High', 'source': 'NHD_import_v0.4_20090914202230', 'NHD:ComID': '159287224', 'SK53_bulk:load': '14010005:FlowLine:34:A', 'name': 'Meadow Creek', 'gnis:feature_id': '00173797', 'attribution': 'NHD'}
# (2) - SK53_bulk - 2009-11-02T11:26:32+00:00, Nodes: 10
# ===============================================================================
# {'geometry': {'coordinates': [[-107.574138, 39.738163],
#                               [-107.574144, 39.738113],
#                               [-107.574163, 39.738005],
#                               [-107.574228, 39.737868],
#                               [-107.574381, 39.737586],
#                               [-107.574868, 39.73689],
#                               [-107.575075, 39.736471],
#                               [-107.5753, 39.735935],
#                               [-107.575362, 39.735744],
#                               [-107.57544, 39.735427]],
#               'type': 'LineString'},
#  'properties': {'@created_at': '2009-11-02T11:26:32+00:00',
#                 '@id': 41062148,
#                 '@object_history': [{'created_at': '2009-09-18T16:42:36+00:00',
#                                      'new_tags': {'NHD:ComID': '159287224',
#                                                   'NHD:FCode': '46006',
#                                                   'NHD:FType': 'StreamRiver',
#                                                   'NHD:RESOLUTION': 'High',
#                                                   'NHD:ReachCode': '14010005000465',
#                                                   'NHD:way_id': '159287224',
#                                                   'SK53_bulk:load': '14010005:FlowLine:34:A',
#                                                   'attribution': 'NHD',
#                                                   'gnis:feature_id': '00173797',
#                                                   'name': 'Meadow Creek',
#                                                   'source': 'NHD_import_v0.4_20090914202230',
#                                                   'waterway': 'stream'},
#                                      'uid': 161206,
#                                      'user': 'SK53_bulk',
#                                      'version': 1},
#                                     {'created_at': '2009-11-02T11:26:32+00:00',
#                                      'geometry_change': {'new': [[-107.574138,
#                                                                   39.738163],
#                                                                  [-107.574144,
#                                                                   39.738113],
#                                                                  [-107.574163,
#                                                                   39.738005],
#                                                                  [-107.574228,
#                                                                   39.737868],
#                                                                  [-107.574381,
#                                                                   39.737586],
#                                                                  [-107.574868,
#                                                                   39.73689],
#                                                                  [-107.575075,
#                                                                   39.736471],
#                                                                  [-107.5753,
#                                                                   39.735935],
#                                                                  [-107.575362,
#                                                                   39.735744],
#                                                                  [-107.57544,
#                                                                   39.735427]],
#                                                          'old': [[-107.574138,
#                                                                   39.738163],
#                                                                  [-107.574144,
#                                                                   39.738113],
#                                                                  [-107.574163,
#                                                                   39.738005],
#                                                                  [-107.574228,
#                                                                   39.737868],
#                                                                  [-107.574381,
#                                                                   39.737586],
#                                                                  [-107.574868,
#                                                                   39.73689],
#                                                                  [-107.575075,
#                                                                   39.736471],
#                                                                  [-107.5753,
#                                                                   39.735935],
#                                                                  [-107.575362,
#                                                                   39.735744],
#                                                                  [-107.57544,
#                                                                   39.735427],
#                                                                  [-107.57544,
#                                                                   39.735427]]},
#                                      'seconds_since_last_edit': 3869036,
#                                      'uid': 161206,
#                                      'user': 'SK53_bulk',
#                                      'version': 2}],
#                 '@uid': 161206,
#                 '@user': 'SK53_bulk',
#                 '@version': 2,
#                 'NHD:ComID': '159287224',
#                 'NHD:FCode': '46006',
#                 'NHD:FType': 'StreamRiver',
#                 'NHD:RESOLUTION': 'High',
#                 'NHD:ReachCode': '14010005000465',
#                 'NHD:way_id': '159287224',
#                 'SK53_bulk:load': '14010005:FlowLine:34:A',
#                 'attribution': 'NHD',
#                 'gnis:feature_id': '00173797',
#                 'name': 'Meadow Creek',
#                 'source': 'NHD_import_v0.4_20090914202230',
#                 'waterway': 'stream'},
#  'type': 'Feature'}
# ID: 116428498; revisions: 18
# -------------------------------------------------------------------------------
# (1) - GPS_dr - 2011-06-05T04:39:34+00:00, Nodes: 7
# 	New Tags: {'service': 'alley', 'highway': 'service'}
# (2) - Your Village Maps - 2015-04-07T06:28:31+00:00, Nodes: 7
# 	New Tags: {'surface': 'concrete'}
# (3) - chachafish - 2015-04-23T06:18:48+00:00, Nodes: 4
# (4) - chachafish - 2015-05-01T07:44:24+00:00, Nodes: 5
# (5) - chachafish - 2015-05-01T07:50:15+00:00, Nodes: 6
# (6) - chachafish - 2015-05-01T08:25:17+00:00, Nodes: 7
# (7) - chachafish - 2015-05-01T13:56:22+00:00, Nodes: 8
# (8) - chachafish - 2015-05-01T14:47:05+00:00, Nodes: 13
# (9) - chachafish - 2015-05-01T16:03:08+00:00, Nodes: 14
# (10) - chachafish - 2015-05-01T16:04:21+00:00, Nodes: 15
# (11) - chachafish - 2015-05-01T16:05:21+00:00, Nodes: 16
# (12) - chachafish - 2015-05-02T10:49:04+00:00, Nodes: 17
# (13) - chachafish - 2015-05-02T10:51:38+00:00, Nodes: 18
# (14) - chachafish - 2015-05-02T11:05:00+00:00, Nodes: 19
# (15) - chachafish - 2015-05-04T05:26:15+00:00, Nodes: 20
# (16) - chachafish - 2016-04-19T15:44:52+00:00, Nodes: 21
# (17) - chachafish - 2016-04-19T15:49:01+00:00, Nodes: 23
# (18) - chachafish - 2016-04-19T15:50:02+00:00, Nodes: 24
# (19) - chachafish - 2016-04-19T16:57:34+00:00, Nodes: 25
# ===============================================================================
# {'geometry': {'coordinates': [[-105.0009089, 39.7300089],
#                               [-105.0009093, 39.7298455],
#                               [-105.0009106, 39.7292562],
#                               [-105.0009111, 39.7290164],
#                               [-105.0009113, 39.7289291],
#                               [-105.0009115, 39.7288168],
#                               [-105.0009123, 39.72838],
#                               [-105.0009126, 39.7282217],
#                               [-105.0009128, 39.7280954],
#                               [-105.0009132, 39.7278906],
#                               [-105.0009135, 39.7277493],
#                               [-105.0009136, 39.7276843],
#                               [-105.0009141, 39.7273922],
#                               [-105.0009136, 39.7273148],
#                               [-105.0009138, 39.727228],
#                               [-105.0009146, 39.7267674],
#                               [-105.0009149, 39.7266178],
#                               [-105.0009151, 39.7264755],
#                               [-105.0009161, 39.7259322],
#                               [-105.0009178, 39.7259066],
#                               [-105.0009244, 39.7258833],
#                               [-105.0009466, 39.7258679],
#                               [-105.0009727, 39.7258606],
#                               [-105.0015079, 39.725863],
#                               [-105.00161, 39.7258634]],
#               'type': 'LineString'},
#  'properties': {'@created_at': '2016-04-19T16:57:34+00:00',
#                 '@id': 116428498,
#                 '@object_history': [{'created_at': '2011-06-05T04:39:34+00:00',
#                                      'new_tags': {'highway': 'service',
#                                                   'service': 'alley'},
#                                      'uid': 117055,
#                                      'user': 'GPS_dr',
#                                      'version': 1},
#                                     {'created_at': '2015-04-07T06:28:31+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300077],
#                                                                  [-105.0009105,
#                                                                   39.7289107],
#                                                                  [-105.0009116,
#                                                                   39.7273148],
#                                                                  [-105.0009137,
#                                                                   39.7259308],
#                                                                  [-105.0009244,
#                                                                   39.7258833],
#                                                                  [-105.0009727,
#                                                                   39.7258606],
#                                                                  [-105.0016041,
#                                                                   39.7258634]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300077],
#                                                                  [-105.0008928,
#                                                                   39.7289115],
#                                                                  [-105.0009116,
#                                                                   39.7273175],
#                                                                  [-105.0009137,
#                                                                   39.7259308],
#                                                                  [-105.0009244,
#                                                                   39.7258833],
#                                                                  [-105.0009727,
#                                                                   39.7258606],
#                                                                  [-105.0016041,
#                                                                   39.7258634]]},
#                                      'new_tags': {'surface': 'concrete'},
#                                      'seconds_since_last_edit': 121139337,
#                                      'uid': 227972,
#                                      'user': 'Your Village Maps',
#                                      'version': 2},
#                                     {'created_at': '2015-04-23T06:18:48+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300077],
#                                                                  [-105.0009108,
#                                                                   39.7289091],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009161,
#                                                                   39.7259322]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300077],
#                                                                  [-105.0009105,
#                                                                   39.7289107],
#                                                                  [-105.0009116,
#                                                                   39.7273148],
#                                                                  [-105.0009137,
#                                                                   39.7259308],
#                                                                  [-105.0009244,
#                                                                   39.7258833],
#                                                                  [-105.0009727,
#                                                                   39.7258606],
#                                                                  [-105.0016041,
#                                                                   39.7258634]]},
#                                      'seconds_since_last_edit': 1381817,
#                                      'uid': 2237750,
#                                      'user': 'chachafish',
#                                      'version': 3},
#                                     {'created_at': '2015-05-01T07:44:24+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009161,
#                                                                   39.7259322]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300077],
#                                                                  [-105.0009108,
#                                                                   39.7289091],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009161,
#                                                                   39.7259322]]},
#                                      'seconds_since_last_edit': 696336,
#                                      'uid': 2237750,
#                                      'user': 'chachafish',
#                                      'version': 4},
#                                     {'created_at': '2015-05-01T07:50:15+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009161,
#                                                                   39.7259322]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009161,
#                                                                   39.7259322]]},
#                                      'seconds_since_last_edit': 351,
#                                      'uid': 2237750,
#                                      'user': 'chachafish',
#                                      'version': 5},
#                                     {'created_at': '2015-05-01T08:25:17+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009161,
#                                                                   39.7259322]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009161,
#                                                                   39.7259322]]},
#                                      'seconds_since_last_edit': 2102,
#                                      'uid': 2237750,
#                                      'user': 'chachafish',
#                                      'version': 6},
#                                     {'created_at': '2015-05-01T13:56:22+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009141,
#                                                                   39.7273922],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009161,
#                                                                   39.7259322]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009161,
#                                                                   39.7259322]]},
#                                      'seconds_since_last_edit': 19865,
#                                      'uid': 2237750,
#                                      'user': 'chachafish',
#                                      'version': 7},
#                                     {'created_at': '2015-05-01T14:47:05+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009141,
#                                                                   39.7273922],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009161,
#                                                                   39.7259322],
#                                                                  [-105.0009178,
#                                                                   39.7259066],
#                                                                  [-105.0009244,
#                                                                   39.7258833],
#                                                                  [-105.0009466,
#                                                                   39.7258679],
#                                                                  [-105.0009727,
#                                                                   39.7258606],
#                                                                  [-105.00161,
#                                                                   39.7258634]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009141,
#                                                                   39.7273922],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009161,
#                                                                   39.7259322]]},
#                                      'seconds_since_last_edit': 3043,
#                                      'uid': 2237750,
#                                      'user': 'chachafish',
#                                      'version': 8},
#                                     {'created_at': '2015-05-01T16:03:08+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009141,
#                                                                   39.7273922],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009151,
#                                                                   39.7264755],
#                                                                  [-105.0009161,
#                                                                   39.7259322],
#                                                                  [-105.0009178,
#                                                                   39.7259066],
#                                                                  [-105.0009244,
#                                                                   39.7258833],
#                                                                  [-105.0009466,
#                                                                   39.7258679],
#                                                                  [-105.0009727,
#                                                                   39.7258606],
#                                                                  [-105.00161,
#                                                                   39.7258634]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009141,
#                                                                   39.7273922],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009161,
#                                                                   39.7259322],
#                                                                  [-105.0009178,
#                                                                   39.7259066],
#                                                                  [-105.0009244,
#                                                                   39.7258833],
#                                                                  [-105.0009466,
#                                                                   39.7258679],
#                                                                  [-105.0009727,
#                                                                   39.7258606],
#                                                                  [-105.00161,
#                                                                   39.7258634]]},
#                                      'seconds_since_last_edit': 4563,
#                                      'uid': 2237750,
#                                      'user': 'chachafish',
#                                      'version': 9},
#                                     {'created_at': '2015-05-01T16:04:21+00:00',
#                                      'geometry_change': {'new': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
#                                                                  [-105.0009113,
#                                                                   39.7289291],
#                                                                  [-105.0009115,
#                                                                   39.7288168],
#                                                                  [-105.0009141,
#                                                                   39.7273922],
#                                                                  [-105.0009136,
#                                                                   39.7273148],
#                                                                  [-105.0009138,
#                                                                   39.727228],
#                                                                  [-105.0009146,
#                                                                   39.7267674],
#                                                                  [-105.0009151,
#                                                                   39.7264755],
#                                                                  [-105.0009161,
#                                                                   39.7259322],
#                                                                  [-105.0009178,
#                                                                   39.7259066],
#                                                                  [-105.0009244,
#                                                                   39.7258833],
#                                                                  [-105.0009466,
#                                                                   39.7258679],
#                                                                  [-105.0009727,
#                                                                   39.7258606],
#                                                                  [-105.00161,
#                                                                   39.7258634]],
#                                                          'old': [[-105.0009089,
#                                                                   39.7300089],
#                                                                  [-105.0009111,
#                                                                   39.7290164],
# ...
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Clear '
#                                                                   'Creek, '
#                                                                   'CO',
#                                                   'tiger:tlid': '179836942',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-4525b5d3-1172-4e6b-8ebc-8e55c7408caa'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-10-01T20:24:15+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Clear '
#                                                                       'Creek, '
#                                                                       'CO',
#                                                       'tiger:tlid': '179836942',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-4525b5d3-1172-4e6b-8ebc-8e55c7408caa'},
#                                      'seconds_since_last_edit': 56461419,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# ID: 119558823; revisions: 1
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-11-17T15:33:17+00:00, Nodes: 2
# 	New Tags: {'tiger:tlid': '161423542:161424281:161424282:161421741:161421743', 'source': 'tiger_import_dch_v0.6_20070810', 'tiger:upload_uuid': 'bulk_upload.pl-6d24c801-e6cd-485b-b723-84209b90bdd4', 'tiger:county': 'Cheyenne, KS'}
# (2) - woodpeck_fixbot - 2009-11-06T17:50:11+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:tlid': '161423542:161424281:161424282:161421741:161421743', 'source': 'tiger_import_dch_v0.6_20070810', 'tiger:county': 'Cheyenne, KS', 'tiger:upload_uuid': 'bulk_upload.pl-6d24c801-e6cd-485b-b723-84209b90bdd4'}
# ===============================================================================
# {'geometry': {'coordinates': [-101.861153, 39.724109], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-06T17:50:11+00:00',
#                 '@id': 119558823,
#                 '@object_history': [{'created_at': '2007-11-17T15:33:17+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070810',
#                                                   'tiger:county': 'Cheyenne, '
#                                                                   'KS',
#                                                   'tiger:tlid': '161423542:161424281:161424282:161421741:161421743',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-6d24c801-e6cd-485b-b723-84209b90bdd4'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-06T17:50:11+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070810',
#                                                       'tiger:county': 'Cheyenne, '
#                                                                       'KS',
#                                                       'tiger:tlid': '161423542:161424281:161424282:161421741:161421743',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-6d24c801-e6cd-485b-b723-84209b90bdd4'},
#                                      'seconds_since_last_edit': 62216214,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-101.861153, 39.724109], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-06T17:50:11+00:00',
#                 '@id': 119558823,
#                 '@object_history': [{'created_at': '2007-11-17T15:33:17+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070810',
#                                                   'tiger:county': 'Cheyenne, '
#                                                                   'KS',
#                                                   'tiger:tlid': '161423542:161424281:161424282:161421741:161421743',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-6d24c801-e6cd-485b-b723-84209b90bdd4'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-06T17:50:11+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070810',
#                                                       'tiger:county': 'Cheyenne, '
#                                                                       'KS',
#                                                       'tiger:tlid': '161423542:161424281:161424282:161421741:161421743',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-6d24c801-e6cd-485b-b723-84209b90bdd4'},
#                                      'seconds_since_last_edit': 62216214,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# ID: 177228257; revisions: 2
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-18T16:51:31+00:00, Nodes: 2
# 	New Tags: {'tiger:tlid': '104302834:104312451', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-070d8293-ff87-4033-945e-1f1b05bd9e45', 'tiger:county': 'Huerfano, CO'}
# (2) - woodpeck_fixbot - 2009-11-28T04:16:50+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:tlid': '104302834:104312451', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:county': 'Huerfano, CO', 'tiger:upload_uuid': 'bulk_upload.pl-070d8293-ff87-4033-945e-1f1b05bd9e45'}
# (3) - Hedaja - 2016-05-19T14:55:26+00:00, Nodes: 2
# ===============================================================================
# {'geometry': {'coordinates': [-105.2020526, 37.9520149], 'type': 'Point'},
#  'properties': {'@created_at': '2016-05-19T14:55:26+00:00',
#                 '@id': 177228257,
#                 '@object_history': [{'created_at': '2007-12-18T16:51:31+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Huerfano, '
#                                                                   'CO',
#                                                   'tiger:tlid': '104302834:104312451',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-070d8293-ff87-4033-945e-1f1b05bd9e45'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-28T04:16:50+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Huerfano, '
#                                                                       'CO',
#                                                       'tiger:tlid': '104302834:104312451',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-070d8293-ff87-4033-945e-1f1b05bd9e45'},
#                                      'seconds_since_last_edit': 61385119,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2},
#                                     {'created_at': '2016-05-19T14:55:26+00:00',
#                                      'geometry_change': {'new': {'nodes': 2},
#                                                          'old': {'nodes': 2}},
#                                      'seconds_since_last_edit': 204287916,
#                                      'uid': 339917,
#                                      'user': 'Hedaja',
#                                      'version': 3}],
#                 '@uid': 339917,
#                 '@user': 'Hedaja',
#                 '@version': 3},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-105.2020526, 37.9520149], 'type': 'Point'},
#  'properties': {'@created_at': '2016-05-19T14:55:26+00:00',
#                 '@id': 177228257,
#                 '@object_history': [{'created_at': '2007-12-18T16:51:31+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Huerfano, '
#                                                                   'CO',
#                                                   'tiger:tlid': '104302834:104312451',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-070d8293-ff87-4033-945e-1f1b05bd9e45'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-28T04:16:50+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Huerfano, '
#                                                                       'CO',
#                                                       'tiger:tlid': '104302834:104312451',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-070d8293-ff87-4033-945e-1f1b05bd9e45'},
#                                      'seconds_since_last_edit': 61385119,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2},
#                                     {'created_at': '2016-05-19T14:55:26+00:00',
#                                      'geometry_change': {'new': [-105.2020526,
#                                                                  37.9520149],
#                                                          'old': [-105.202412,
#                                                                  37.952241]},
#                                      'seconds_since_last_edit': 204287916,
#                                      'uid': 339917,
#                                      'user': 'Hedaja',
#                                      'version': 3}],
#                 '@uid': 339917,
#                 '@user': 'Hedaja',
#                 '@version': 3},
#  'type': 'Feature'}
# ID: 178177963; revisions: 1
# -------------------------------------------------------------------------------
# (1) - DaveHansenTiger - 2007-12-19T06:53:25+00:00, Nodes: 2
# 	New Tags: {'tiger:tlid': '161471358:161462464:161462466', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:upload_uuid': 'bulk_upload.pl-90f3e4fb-c2c2-458d-9cdd-7ca1a254313f', 'tiger:county': 'Yuma, CO'}
# (2) - woodpeck_fixbot - 2009-11-03T02:12:46+00:00, Nodes: 2
# 	Deleted Tags: {'tiger:tlid': '161471358:161462464:161462466', 'source': 'tiger_import_dch_v0.6_20070809', 'tiger:county': 'Yuma, CO', 'tiger:upload_uuid': 'bulk_upload.pl-90f3e4fb-c2c2-458d-9cdd-7ca1a254313f'}
# ===============================================================================
# {'geometry': {'coordinates': [-102.084674, 39.759805], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-03T02:12:46+00:00',
#                 '@id': 178177963,
#                 '@object_history': [{'created_at': '2007-12-19T06:53:25+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Yuma, '
#                                                                   'CO',
#                                                   'tiger:tlid': '161471358:161462464:161462466',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-90f3e4fb-c2c2-458d-9cdd-7ca1a254313f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-03T02:12:46+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Yuma, '
#                                                                       'CO',
#                                                       'tiger:tlid': '161471358:161462464:161462466',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-90f3e4fb-c2c2-458d-9cdd-7ca1a254313f'},
#                                      'seconds_since_last_edit': 59167161,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}
# {'geometry': {'coordinates': [-102.084674, 39.759805], 'type': 'Point'},
#  'properties': {'@created_at': '2009-11-03T02:12:46+00:00',
#                 '@id': 178177963,
#                 '@object_history': [{'created_at': '2007-12-19T06:53:25+00:00',
#                                      'new_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                   'tiger:county': 'Yuma, '
#                                                                   'CO',
#                                                   'tiger:tlid': '161471358:161462464:161462466',
#                                                   'tiger:upload_uuid': 'bulk_upload.pl-90f3e4fb-c2c2-458d-9cdd-7ca1a254313f'},
#                                      'uid': 7168,
#                                      'user': 'DaveHansenTiger',
#                                      'version': 1},
#                                     {'created_at': '2009-11-03T02:12:46+00:00',
#                                      'deleted_tags': {'source': 'tiger_import_dch_v0.6_20070809',
#                                                       'tiger:county': 'Yuma, '
#                                                                       'CO',
#                                                       'tiger:tlid': '161471358:161462464:161462466',
#                                                       'tiger:upload_uuid': 'bulk_upload.pl-90f3e4fb-c2c2-458d-9cdd-7ca1a254313f'},
#                                      'seconds_since_last_edit': 59167161,
#                                      'uid': 147510,
#                                      'user': 'woodpeck_fixbot',
#                                      'version': 2}],
#                 '@uid': 147510,
#                 '@user': 'woodpeck_fixbot',
#                 '@version': 2},
#  'type': 'Feature'}

# %%
# Write out the geojsonl file
with open('colorado_history_no_geometry.geojsonl','w') as outFile:
    for w_id, way in ways.items():
        outFile.write(json.dumps(way.as_geojson(geometries=False))+"\n")
    
    for n_id, node in nodes.items():
        outFile.write(json.dumps(node.as_geojson(geometries=False))+"\n")

# %% [markdown]
# Tippecanoe Instructions
#
#     $ tippecanoe -o colorado_history_no_geometry.mbtiles -Pf -ps -pt -pf -pk -Z12 -z12 -d14 -l osm -n osm boulder_history.geojsonl
#
# The geometries are stil _not quite right_... but they're close?

# %%
with open('colorado_history_geometry_diffs.geojsonl','w') as outFile:
    for idx, (w_id, way) in enumerate(ways.items()):
        outFile.write(json.dumps(way.as_geojson())+"\n")
        if idx%1000==0:
            sys.stderr.write("\r{0} ways processed".format(idx))
    for idx, (n_id, node) in enumerate(nodes.items()):
        outFile.write(json.dumps(node.as_geojson())+"\n")
        if idx%1000==0:
            sys.stderr.write("\r{0} nodes processed".format(idx))
# Out:
# 3608000 nodes processed
